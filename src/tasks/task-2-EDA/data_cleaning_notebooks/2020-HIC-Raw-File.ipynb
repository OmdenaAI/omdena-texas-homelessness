# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\mohit\OneDrive\Desktop\Omdena-AI\omdena-texas-homelessness\src\data\2020-HIC-Raw-File.xlsx")

# %%
df.head()
# Out:
#     Row # CocState                          CoC  Coc\ID  HudNum     Status  \
# 0  448302       TX     Austin/Travis County CoC    1040  TX-503  Submitted
# 1  413067       TX     Austin/Travis County CoC    1040  TX-503  Submitted
# 2  457823       CA              Lake County CoC    1503  CA-529  Submitted
# 3  450566       MD       Mid-Shore Regional CoC    1288  MD-511  Submitted
# 4  470490       CA  Bakersfield/Kern County CoC    1056  CA-604  Submitted
#
#    year  Organization ID           Organization Name HMIS Org ID  ...  \
# 0  2020            19146                 A New Entry        9315  ...
# 1  2020            19146                 A New Entry        9315  ...
# 2  2020            39948  Hope Harbor Warming Center           2  ...
# 3  2020            38597              His Hope Haven         546  ...
# 4  2020              734  The Mission at Kern County           4  ...
#
#    PIT Count Total Beds          Updated On mergedDefunctYear  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25228 entries, 0 to 25227
# Data columns (total 93 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Row #                                   25228 non-null  int64
#  1   CocState                                25228 non-null  object
#  2   CoC                                     25228 non-null  object
#  3   Coc\ID                                  25228 non-null  int64
#  4   HudNum                                  25228 non-null  object
#  5   Status                                  25228 non-null  object
#  6   year                                    25228 non-null  int64
#  7   Organization ID                         25228 non-null  int64
#  8   Organization Name                       25227 non-null  object
#  9   HMIS Org ID                             25202 non-null  object
# ...

# %%
df.shape
# Out:
# (25228, 93)

# %%
df.isnull().sum()
# Out:
# Row #                                         0
# CocState                                      0
# CoC                                           0
# Coc\ID                                        0
# HudNum                                        0
#                                           ...
# questionDesiresToUseDescriptorElements    20459
# notes                                     21090
# projectNotes                              22578
# sandyRelated                                  0
# sandyRelatedNote                          25225
# Length: 93, dtype: int64

# %%
#This simply does that if 50% of the column is NAN then we will drop it

df.dropna(axis=1, thresh = int(0.4*df.shape[0]), inplace=True)

# %%
df.describe()
# Out:
#                Row #        Coc\ID     year  Organization ID     Project ID  \
# count   25228.000000  25228.000000  25228.0     25228.000000   25228.000000
# mean   432941.459450   1205.298042   2020.0     15179.395711   78865.126962
# std     22987.584603    140.340172      0.0     14486.030708   46838.324208
# min    400961.000000    951.000000   2020.0         1.000000       4.000000
# 25%    409862.750000   1071.000000   2020.0      4261.000000   27585.750000
# 50%    435751.500000   1213.000000   2020.0      8932.000000   98530.500000
# 75%    450386.500000   1336.000000   2020.0     24076.000000  117202.250000
# max    470490.000000   1509.000000   2020.0     44380.000000  138896.000000
#
#             Geo Code  HMIS Participating  mcKinneyVentoEsg  mcKinneyVentoCoc  \
# count   25228.000000        25223.000000      25228.000000      25228.000000
# mean   282646.276122            0.739365          0.123474          0.252933
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25228 entries, 0 to 25227
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Row #                           25228 non-null  int64
#  1   CocState                        25228 non-null  object
#  2   CoC                             25228 non-null  object
#  3   Coc\ID                          25228 non-null  int64
#  4   HudNum                          25228 non-null  object
#  5   Status                          25228 non-null  object
#  6   year                            25228 non-null  int64
#  7   Organization ID                 25228 non-null  int64
#  8   Organization Name               25227 non-null  object
#  9   HMIS Org ID                     25202 non-null  object
#  10  Project ID                      25228 non-null  int64
#  11  Project Name                    25228 non-null  object
# ...

# %%
col = df.columns

# %%
len(col)
# Out:
# 54

# %%
for i in range(len(col)):
    if df[col[i]].dtype == "int64":
        df[col[i]] = df[col[i]].fillna(df[col[i]].mean())
    
    elif df[col[i]].dtype == "float64":
        df[col[i]] = df[col[i]].fillna(df[col[i]].mode()[0])

# %%
df.isnull().sum()
# Out:
# Row #                                0
# CocState                             0
# CoC                                  0
# Coc\ID                               0
# HudNum                               0
# Status                               0
# year                                 0
# Organization ID                      0
# Organization Name                    1
# HMIS Org ID                         26
# Project ID                           0
# Project Name                         0
# HMIS Project ID                     10
# HIC Date                             0
# Project Type                         0
# Geo Code                             0
# HMIS Participating                   0
# Inventory Type                       2
# mcKinneyVentoEsg                     0
# mcKinneyVentoCoc                     0
# mcKinneyVentoSpC                     0
# mcKinneyVentoS8                      0
# mcKinneyVentoShp                     0
# federalFundingVash                   0
# ...

# %%
df.nunique()
# Out:
# Row #                             25228
# CocState                             55
# CoC                                 391
# Coc\ID                              391
# HudNum                              391
# Status                                1
# year                                  1
# Organization ID                    9080
# Organization Name                  8115
# HMIS Org ID                        5056
# Project ID                        25169
# Project Name                      22218
# HMIS Project ID                   11904
# HIC Date                             13
# Project Type                          6
# Geo Code                           2279
# HMIS Participating                    2
# Inventory Type                        2
# mcKinneyVentoEsg                      2
# mcKinneyVentoCoc                      2
# mcKinneyVentoSpC                      2
# mcKinneyVentoS8                       2
# mcKinneyVentoShp                      2
# ...

# %%
n = int(.08 * df.shape[0])

for i in range(len(col)):
    if df[col[i]].nunique() > n :
        df.drop([col[i]] , axis=1 , inplace=True)

# %%
df.shape
# Out:
# (25228, 42)

# %%
df.head()
# Out:
#   CocState                          CoC  Coc\ID  HudNum     Status  year  \
# 0       TX     Austin/Travis County CoC    1040  TX-503  Submitted  2020
# 1       TX     Austin/Travis County CoC    1040  TX-503  Submitted  2020
# 2       CA              Lake County CoC    1503  CA-529  Submitted  2020
# 3       MD       Mid-Shore Regional CoC    1288  MD-511  Submitted  2020
# 4       CA  Bakersfield/Kern County CoC    1056  CA-604  Submitted  2020
#
#     HIC Date Project Type  HMIS Participating Inventory Type  ...  \
# 0 2020-01-25           SH                 1.0              C  ...
# 1 2020-01-25           SH                 1.0              C  ...
# 2 2020-01-27           ES                 0.0              C  ...
# 3 2020-01-29           ES                 0.0              C  ...
# 4 2020-01-24           ES                 1.0              C  ...
#
#    Youth Beds HH w/ Children  Beds HH w/o Children  \
# 0                        0.0                  25.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25228 entries, 0 to 25227
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CocState                        25228 non-null  object
#  1   CoC                             25228 non-null  object
#  2   Coc\ID                          25228 non-null  int64
#  3   HudNum                          25228 non-null  object
#  4   Status                          25228 non-null  object
#  5   year                            25228 non-null  int64
#  6   HIC Date                        25228 non-null  datetime64[ns]
#  7   Project Type                    25228 non-null  object
#  8   HMIS Participating              25228 non-null  float64
#  9   Inventory Type                  25226 non-null  object
#  10  mcKinneyVentoEsg                25228 non-null  int64
#  11  mcKinneyVentoCoc                25228 non-null  int64
# ...

# %%
# AS this column is of date and time and it will be of no use to us

df.drop(['HIC Date'] , axis=1 , inplace=True)

# %%
df.isnull().sum()
# Out:
# CocState                             0
# CoC                                  0
# Coc\ID                               0
# HudNum                               0
# Status                               0
# year                                 0
# Project Type                         0
# HMIS Participating                   0
# Inventory Type                       2
# mcKinneyVentoEsg                     0
# mcKinneyVentoCoc                     0
# mcKinneyVentoSpC                     0
# mcKinneyVentoS8                      0
# mcKinneyVentoShp                     0
# federalFundingVash                   0
# federalFundingSsvf                   0
# federalFundingGpd                    0
# federalFundingHchv                   0
# federalFundingBcp                    0
# federalFundingTlp                    0
# federalFundingMgh                    0
# federalFundingRhyDp                  0
# federalFundingHopwa                  0
# federalFundingPih                    0
# ...

# %%
df.to_csv(r'C:\Users\mohit\OneDrive\Desktop\Omdena-AI\omdena-texas-homelessness\src\cleaned data\2020-HIC-Cleaned-File.csv')
