# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\mohit\OneDrive\Desktop\Omdena-AI\omdena-texas-homelessness\src\data\Apartment_List_Rent_estimates_texas_2021.csv")

# %%
df.head()
# Out:
#        County_Name  FIPS_Code  Population Bedroom_Size  2017_01  2017_02  \
# 0  Bell County, TX      48027      342236     _Overall   947.00    943.0
# 1  Bell County, TX      48027      342236      _Studio   717.00    714.0
# 2  Bell County, TX      48027      342236          1br   656.00    653.0
# 3  Bell County, TX      48027      342236          2br   828.00    825.0
# 4  Bell County, TX      48027      342236          3br  1127.00   1122.0
#
#    2017_03  2017_04  2017_05  2017_06  ... 2020_11  2020_12 2021_01  2021_02  \
# 0   942.00   942.00   946.00    953.0  ...  1111.0   1108.0  1107.0   1108.0
# 1   713.00   713.00   716.00    721.0  ...   840.0    838.0   838.0    839.0
# 2   652.00   652.00   655.00    660.0  ...   770.0    767.0   767.0    768.0
# 3   824.00   824.00   827.00    834.0  ...   971.0    969.0   968.0    969.0
# 4  1120.00  1120.00  1125.00   1134.0  ...  1321.0   1318.0  1317.0   1318.0
#
#   2021_03 2021_04  2021_05  2021_06  2021_07  2021_08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 60 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   County_Name   216 non-null    object
#  1   FIPS_Code     216 non-null    int64
#  2   Population    216 non-null    int64
#  3   Bedroom_Size  216 non-null    object
#  4   2017_01       216 non-null    object
#  5   2017_02       216 non-null    float64
#  6   2017_03       216 non-null    object
#  7   2017_04       216 non-null    object
#  8   2017_05       216 non-null    object
#  9   2017_06       216 non-null    float64
#  10  2017_07       216 non-null    object
#  11  2017_08       216 non-null    float64
#  12  2017_09       216 non-null    object
#  13  2017_10       216 non-null    float64
#  14  2017_11       216 non-null    object
#  15  2017_12       216 non-null    object
#  16  2018_01       216 non-null    float64
#  17  2018_02       216 non-null    float64
# ...

# %%
df.describe()
# Out:
#           FIPS_Code    Population      2017_02      2017_06      2017_08  \
# count    216.000000  2.160000e+02   216.000000   216.000000   216.000000
# mean   48243.833333  6.277800e+05  1071.814815  1103.675926  1109.055556
# std      144.702453  8.883301e+05   349.650075   357.371719   357.632079
# min    48027.000000  9.197000e+04   427.000000   509.000000   514.000000
# 25%    48131.500000  1.528435e+05   828.000000   852.500000   850.250000
# 50%    48212.000000  2.783320e+05  1048.000000  1049.000000  1060.500000
# 75%    48370.500000  7.562682e+05  1267.000000  1298.500000  1317.750000
# max    48491.000000  4.602523e+06  2164.000000  2219.000000  2222.000000
#
#            2017_10      2018_01      2018_02      2018_03      2018_04  ...  \
# count   216.000000   216.000000   216.000000   216.000000   216.000000  ...
# mean   1108.300926  1112.185185  1111.245370  1117.106481  1123.018519  ...
# std     349.949149   343.926402   343.758907   348.157105   350.619292  ...
# ...

# %%
df.isnull().sum()
# Out:
# County_Name     0
# FIPS_Code       0
# Population      0
# Bedroom_Size    0
# 2017_01         0
# 2017_02         0
# 2017_03         0
# 2017_04         0
# 2017_05         0
# 2017_06         0
# 2017_07         0
# 2017_08         0
# 2017_09         0
# 2017_10         0
# 2017_11         0
# 2017_12         0
# 2018_01         0
# 2018_02         0
# 2018_03         0
# 2018_04         0
# 2018_05         0
# 2018_06         0
# 2018_07         0
# 2018_08         0
# 2018_09         0
# 2018_10         0
# 2018_11         0
# 2018_12         0
# 2019_01         0
# 2019_02         0
# 2019_03         0
# 2019_04         0
# 2019_05         0
# 2019_06         0
# 2019_07         0
# 2019_08         0
# 2019_09         0
# 2019_10         0
# 2019_11         0
# 2019_12         0
# 2020_01         0
# 2020_02         0
# 2020_03         0
# 2020_04         0
# 2020_05         0
# 2020_06         0
# 2020_07         0
# 2020_08         0
# 2020_09         0
# 2020_10         0
# ...

# %%
df.nunique()
# Out:
# County_Name      36
# FIPS_Code        36
# Population       36
# Bedroom_Size      6
# 2017_01         187
# 2017_02         192
# 2017_03         196
# 2017_04         198
# 2017_05         188
# 2017_06         195
# 2017_07         194
# 2017_08         203
# 2017_09         192
# 2017_10         184
# 2017_11         190
# 2017_12         191
# 2018_01         203
# 2018_02         194
# 2018_03         200
# 2018_04         204
# 2018_05         191
# 2018_06         199
# 2018_07         194
# 2018_08         196
# 2018_09         190
# 2018_10         190
# 2018_11         193
# 2018_12         200
# 2019_01         201
# 2019_02         201
# 2019_03         193
# 2019_04         193
# 2019_05         191
# 2019_06         197
# 2019_07         199
# 2019_08         204
# 2019_09         198
# 2019_10         200
# 2019_11         195
# 2019_12         200
# 2020_01         191
# 2020_02         194
# 2020_03         200
# 2020_04         195
# 2020_05         199
# ...

# %%
df.shape
# Out:
# (216, 60)

# %%
n = int(0.2 * df.shape[0])

col = df.columns

for i in range(len(col)):

    if df[col[i]].nunique() > n:
        df.drop([col[i]] , axis=1,inplace=True)

# %%
df.shape
# Out:
# (216, 4)

# %%
categorical_cols = ['County_Name' , 'Bedroom_Size'] 

from sklearn.preprocessing import LabelEncoder

# instantiate labelencoder object
le = LabelEncoder()

# apply le on categorical feature columns
df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))
    
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

#One-hot-encode the categorical columns.
#Unfortunately outputs an array instead of dataframe.
array_hot_encoded = ohe.fit_transform(df[categorical_cols])

#Convert it to df
data_hot_encoded = pd.DataFrame(array_hot_encoded, index=df.index)

#Extract only the columns that didnt need to be encoded
data_other_cols = df.drop(columns=categorical_cols)

#Concatenate the two dataframes : 
data_out = pd.concat([data_hot_encoded, data_other_cols], axis=1)

# %%
df.shape
# Out:
# (216, 4)

# %%
df.head()
# Out:
#    County_Name  FIPS_Code  Population  Bedroom_Size
# 0            0      48027      342236             4
# 1            0      48027      342236             5
# 2            0      48027      342236             0
# 3            0      48027      342236             1
# 4            0      48027      342236             2

# %%
df.to_csv(r'C:\Users\mohit\OneDrive\Desktop\Omdena-AI\omdena-texas-homelessness\src\cleaned data\Apartment_List_Rent_Estimates_texas_county_2021_8.csv')
