# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\mohit\OneDrive\Desktop\omdena-texas-homelessness\src\data\income_related\Tx_IncomePovertyStats.xlsx')

# %%
df.head()
# Out:
#      County Per Capita Income Total Personal Income Median Household Income  \
# 0  Anderson           $36,027        $2,080,020,000                 $48,461
# 1   Andrews           $51,769          $968,334,000                 $74,918
# 2  Angelina           $39,644        $3,437,761,000                 $51,750
# 3   Aransas           $51,614        $1,213,451,000                 $53,085
# 4    Archer           $52,335          $447,617,000                 $63,731
#
#   Average Annual Pay  % of Population in Poverty  \
# 0            $45,799                        19.8
# 1            $69,845                        10.2
# 2            $40,974                        15.6
# 3            $39,316                        18.7
# 4            $38,006                        10.3
#
#    % of Population Under 18 in Poverty
# 0                                 23.8
# 1                                 12.7
# 2                                 22.6
# 3                                 32.1
# 4                                 12.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   County                               254 non-null    object
#  1   Per Capita Income                    254 non-null    object
#  2   Total Personal Income                254 non-null    object
#  3   Median Household Income              254 non-null    object
#  4   Average Annual Pay                   254 non-null    object
#  5   % of Population in Poverty           254 non-null    float64
#  6   % of Population Under 18 in Poverty  254 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 14.0+ KB

# %%
df.shape
# Out:
# (254, 7)

# %%
df.describe()
# Out:
#        % of Population in Poverty  % of Population Under 18 in Poverty
# count                  254.000000                           254.000000
# mean                    15.456299                            22.242913
# std                      5.036933                             7.512878
# min                      4.800000                             6.500000
# 25%                     11.950000                            17.400000
# 50%                     14.850000                            22.050000
# 75%                     18.325000                            26.600000
# max                     32.500000                            44.400000

# %%
categorical_col = df.select_dtypes('object').columns

# %%
categorical_col
# Out:
# Index(['County', 'Per Capita Income', 'Total Personal Income',
#        'Median Household Income', 'Average Annual Pay'],
#       dtype='object')

# %%
len(categorical_col)
# Out:
# 5

# %%
num_col = df.select_dtypes('float64').columns

# %%
num_col
# Out:
# Index(['% of Population in Poverty', '% of Population Under 18 in Poverty'], dtype='object')

# %% [markdown]
# # Checking NULL Values

# %%
df.isnull()
# Out:
#      County  Per Capita Income  Total Personal Income  \
# 0     False              False                  False
# 1     False              False                  False
# 2     False              False                  False
# 3     False              False                  False
# 4     False              False                  False
# ..      ...                ...                    ...
# 249   False              False                  False
# 250   False              False                  False
# 251   False              False                  False
# 252   False              False                  False
# 253   False              False                  False
#
#      Median Household Income  Average Annual Pay  % of Population in Poverty  \
# 0                      False               False                       False
# 1                      False               False                       False
# 2                      False               False                       False
# 3                      False               False                       False
# 4                      False               False                       False
# ..                       ...                 ...                         ...
# 249                    False               False                       False
# 250                    False               False                       False
# 251                    False               False                       False
# 252                    False               False                       False
# 253                    False               False                       False
#
#      % of Population Under 18 in Poverty
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ..                                   ...
# 249                                False
# 250                                False
# 251                                False
# 252                                False
# 253                                False
#
# [254 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# County                                 0
# Per Capita Income                      0
# Total Personal Income                  0
# Median Household Income                0
# Average Annual Pay                     0
# % of Population in Poverty             0
# % of Population Under 18 in Poverty    0
# dtype: int64

# %% [markdown]
# # Checking the Unique Values

# %%
df.nunique()
# Out:
# County                                 254
# Per Capita Income                      253
# Total Personal Income                  254
# Median Household Income                254
# Average Annual Pay                     254
# % of Population in Poverty             131
# % of Population Under 18 in Poverty    171
# dtype: int64

# %% [markdown]
# # Removing Dollar Sign

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–","$"]
# col = ['Per Capita Income','Total Personal Income','Median Household Income','Average Annual Pay']

col = df.columns

for i in range(len(spec_chars)):
    for j in range(1,5):
        df[col[j]] = df[col[j]].str.replace(spec_chars[i] , "")
# Out:
# C:\Users\mohit\AppData\Local\Temp/ipykernel_17416/1780101475.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col[j]] = df[col[j]].str.replace(spec_chars[i] , "")

# %%
col = df.columns

# %%
len(spec_chars)
# Out:
# 33

# %%
df['Per Capita Income'].str.replace('$',"")
# Out:
# C:\Users\mohit\AppData\Local\Temp/ipykernel_17416/3258632343.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Per Capita Income'].str.replace('$',"")
# 0      36027
# 1      51769
# 2      39644
# 3      51614
# 4      52335
#        ...
# 249    39803
# 250    44932
# 251    50732
# 252    28936
# 253    30779
# Name: Per Capita Income, Length: 254, dtype: object

# %%
df.head()
# Out:
#      County Per Capita Income Total Personal Income Median Household Income  \
# 0  Anderson             36027            2080020000                   48461
# 1   Andrews             51769             968334000                   74918
# 2  Angelina             39644            3437761000                   51750
# 3   Aransas             51614            1213451000                   53085
# 4    Archer             52335             447617000                   63731
#
#   Average Annual Pay  % of Population in Poverty  \
# 0              45799                        19.8
# 1              69845                        10.2
# 2              40974                        15.6
# 3              39316                        18.7
# 4              38006                        10.3
#
#    % of Population Under 18 in Poverty
# 0                                 23.8
# 1                                 12.7
# 2                                 22.6
# 3                                 32.1
# 4                                 12.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   County                               254 non-null    object
#  1   Per Capita Income                    254 non-null    object
#  2   Total Personal Income                254 non-null    object
#  3   Median Household Income              254 non-null    object
#  4   Average Annual Pay                   254 non-null    object
#  5   % of Population in Poverty           254 non-null    float64
#  6   % of Population Under 18 in Poverty  254 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 14.0+ KB

# %%
col = df.columns

for i in range(1,5):
    df[col[i]] = pd.to_numeric(df[col[i]], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   County                               254 non-null    object
#  1   Per Capita Income                    254 non-null    int64
#  2   Total Personal Income                254 non-null    int64
#  3   Median Household Income              254 non-null    int64
#  4   Average Annual Pay                   254 non-null    int64
#  5   % of Population in Poverty           254 non-null    float64
#  6   % of Population Under 18 in Poverty  254 non-null    float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 14.0+ KB

# %%
df.shape
# Out:
# (254, 7)

# %%
df.to_csv(r'C:\Users\mohit\OneDrive\Desktop\omdena-texas-homelessness\src\not_encoded_data\poverty_stats.csv')

# %% [markdown]
# # EDA
#
# 1. Visualization and Normalizing ( seaborn , matplotlib, plotly)
# 2. Feature Engineering (PCA - Dimensionality reduction)
# 3. Statistical Modelling

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# we can use this to check the correlation between each of the int_col
col = df.columns

sns.pairplot(df[col])

# %%
# Correlation Matrix Heatmap
f, ax = plt.subplots(figsize=(10, 6))
corr = df[col].corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Heatmap of Poverty Stats', fontsize=14)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

        
def time_series_plot(df):
    """Given dataframe, generate times series plot of numeric data by daily, monthly and yearly frequency"""
    print("\nTo check time series of numeric data  by daily, monthly and yearly frequency")
    if len(df.select_dtypes(include='datetime64').columns)>0:
        for col in df.select_dtypes(include='datetime64').columns:
            for p in ['D', 'M', 'Y']:
                if p=='D':
                    print("Plotting daily data")
                elif p=='M':
                    print("Plotting monthly data")
                else:
                    print("Plotting yearly data")
                for col_num in df.select_dtypes(include=np.number).columns:
                    __ = df.copy()
                    __ = __.set_index(col)
                    __T = __.resample(p).sum()
                    ax = __T[[col_num]].plot()
                    ax.set_ylim(bottom=0)
                    ax.get_yaxis().set_major_formatter(
                    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
                    plt.show()

                    
def numeric_eda(df, hue=None):
    """Given dataframe, generate EDA of numeric data"""
    print("\nTo check: \nDistribution of numeric data")
    display(df.describe().T)
    columns = df.select_dtypes(include=np.number).columns
    figure = plt.figure(figsize=(20, 10))
    figure.add_subplot(1, len(columns), 1)
    for index, col in enumerate(columns):
        if index > 0:
            figure.add_subplot(1, len(columns), index + 1)
        sns.boxplot(y=col, data=df, boxprops={'facecolor': 'None'})
    figure.tight_layout()
    plt.show()
    
    if len(df.select_dtypes(include='category').columns) > 0:
        for col_num in df.select_dtypes(include=np.number).columns:
            for col in df.select_dtypes(include='category').columns:
                fig = sns.catplot(x=col, y=col_num, kind='violin', data=df, height=5, aspect=2)
                fig.set_xticklabels(rotation=90)
                plt.show()
    
    # Plot the pairwise joint distributions
    print("\nTo check pairwise joint distribution of numeric data")
    if hue==None:
        sns.pairplot(df.select_dtypes(include=np.number))
    else:
        sns.pairplot(df.select_dtypes(include=np.number).join(df[[hue]]), hue=hue)
    plt.show()


def top5(df):
    """Given dataframe, generate top 5 unique values for non-numeric data"""
    columns = df.select_dtypes(include=['object', 'category']).columns
    for col in columns:
        print("Top 5 unique values of " + col)
        print(df[col].value_counts().reset_index().rename(columns={"index": col, col: "Count"})[
              :min(5, len(df[col].value_counts()))])
        print(" ")
    
    
def categorical_eda(df, hue=None):
    """Given dataframe, generate EDA of categorical data"""
    print("\nTo check: \nUnique count of non-numeric data\n")
    print(df.select_dtypes(include=['object', 'category']).nunique())
    top5(df)
    # Plot count distribution of categorical data
    for col in df.select_dtypes(include='category').columns:
        fig = sns.catplot(x=col, kind="count", data=df, hue=hue)
        fig.set_xticklabels(rotation=90)
        plt.show()
    

def eda(df):
    """Given dataframe, generate exploratory data analysis"""
    # check that input is pandas dataframe
    if type(df) != pd.core.frame.DataFrame:
        raise TypeError("Only pandas dataframe is allowed as input")
        
    # replace field that's entirely space (or empty) with NaN
    df = df.replace(r'^\s*$', np.nan, regex=True)

    print("Preview of data:")
    display(df.head(3))

    print("\nTo check: \n (1) Total number of entries \n (2) Column types \n (3) Any null values\n")
    print(df.info())

    # generate preview of entries with null values
    if df.isnull().any(axis=None):
        print("\nPreview of data with null values:")
        display(df[df.isnull().any(axis=1)].head(3))
        missingno.matrix(df)
        plt.show()

    # generate count statistics of duplicate entries
    if len(df[df.duplicated()]) > 0:
        print("\n***Number of duplicated entries: ", len(df[df.duplicated()]))
        display(df[df.duplicated(keep=False)].sort_values(by=list(df.columns)).head())
    else:
        print("\nNo duplicated entries found")

    # EDA of categorical data
    categorical_eda(df)
    
    # EDA of numeric data
    numeric_eda(df)
        
    # Plot time series plot of numeric data
    time_series_plot(df)

# %%
numeric_eda(df)
# Out:
# To check:
# Distribution of numeric data
#                                      count          mean           std  \
# Per Capita Income                    254.0  4.647892e+04  1.271955e+04
# Total Personal Income                254.0  6.028923e+09  2.404490e+10
# Median Household Income              254.0  5.495818e+04  1.334813e+04
# Average Annual Pay                   254.0  4.616093e+04  1.042815e+04
# % of Population in Poverty           254.0  1.545630e+01  5.036933e+00
# % of Population Under 18 in Poverty  254.0  2.224291e+01  7.512878e+00
#
#                                            min           25%           50%  \
# Per Capita Income                      23569.0  3.960900e+04  4.430200e+04
# Total Personal Income                9081000.0  3.109718e+08  8.423690e+08
# Median Household Income                31410.0  4.577525e+04  5.270300e+04
# Average Annual Pay                     27058.0  3.932500e+04  4.350950e+04
# % of Population in Poverty                 4.8  1.195000e+01  1.485000e+01
# % of Population Under 18 in Poverty        6.5  1.740000e+01  2.205000e+01
#
#                                               75%           max
# Per Capita Income                    5.071525e+04  1.309830e+05
# Total Personal Income                2.169747e+09  2.828092e+11
# Median Household Income              6.134350e+04  1.057630e+05
# Average Annual Pay                   5.028400e+04  8.561800e+04
# % of Population in Poverty           1.832500e+01  3.250000e+01
# % of Population Under 18 in Poverty  2.660000e+01  4.440000e+01
# To check pairwise joint distribution of numeric data

# %%
categorical_eda(df)
# Out:
# To check:
# Unique count of non-numeric data
#
# County    254
# dtype: int64
# Top 5 unique values of County
#      County  Count
# 0  Anderson      1
# 1   Navarro      1
# 2  McMullen      1
# 3    Medina      1
# 4    Menard      1

# %%
top5(df)
# Out:
# Top 5 unique values of County
#      County  Count
# 0  Anderson      1
# 1   Navarro      1
# 2  McMullen      1
# 3    Medina      1
# 4    Menard      1

# %%
eda(df)
# Out:
# Preview of data:
#      County  Per Capita Income  Total Personal Income  \
# 0  Anderson              36027             2080020000
# 1   Andrews              51769              968334000
# 2  Angelina              39644             3437761000
#
#    Median Household Income  Average Annual Pay  % of Population in Poverty  \
# 0                    48461               45799                        19.8
# 1                    74918               69845                        10.2
# 2                    51750               40974                        15.6
#
#    % of Population Under 18 in Poverty
# 0                                 23.8
# 1                                 12.7
# 2                                 22.6
# To check:
#  (1) Total number of entries
#  (2) Column types
#  (3) Any null values
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   County                               254 non-null    object
#  1   Per Capita Income                    254 non-null    int64
#  2   Total Personal Income                254 non-null    int64
#  3   Median Household Income              254 non-null    int64
#  4   Average Annual Pay                   254 non-null    int64
#  5   % of Population in Poverty           254 non-null    float64
#  6   % of Population Under 18 in Poverty  254 non-null    float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 14.0+ KB
# None
#
# No duplicated entries found
#
# To check:
# Unique count of non-numeric data
#
# County    254
# dtype: int64
# Top 5 unique values of County
#      County  Count
# 0  Anderson      1
# 1   Navarro      1
# 2  McMullen      1
# 3    Medina      1
# 4    Menard      1
#
#
# To check:
# Distribution of numeric data
#                                      count          mean           std  \
# Per Capita Income                    254.0  4.647892e+04  1.271955e+04
# Total Personal Income                254.0  6.028923e+09  2.404490e+10
# Median Household Income              254.0  5.495818e+04  1.334813e+04
# Average Annual Pay                   254.0  4.616093e+04  1.042815e+04
# % of Population in Poverty           254.0  1.545630e+01  5.036933e+00
# % of Population Under 18 in Poverty  254.0  2.224291e+01  7.512878e+00
#
#                                            min           25%           50%  \
# Per Capita Income                      23569.0  3.960900e+04  4.430200e+04
# Total Personal Income                9081000.0  3.109718e+08  8.423690e+08
# Median Household Income                31410.0  4.577525e+04  5.270300e+04
# Average Annual Pay                     27058.0  3.932500e+04  4.350950e+04
# % of Population in Poverty                 4.8  1.195000e+01  1.485000e+01
# % of Population Under 18 in Poverty        6.5  1.740000e+01  2.205000e+01
#
#                                               75%           max
# Per Capita Income                    5.071525e+04  1.309830e+05
# Total Personal Income                2.169747e+09  2.828092e+11
# Median Household Income              6.134350e+04  1.057630e+05
# Average Annual Pay                   5.028400e+04  8.561800e+04
# % of Population in Poverty           1.832500e+01  3.250000e+01
# % of Population Under 18 in Poverty  2.660000e+01  4.440000e+01
# To check pairwise joint distribution of numeric data
# To check time series of numeric data  by daily, monthly and yearly frequency
