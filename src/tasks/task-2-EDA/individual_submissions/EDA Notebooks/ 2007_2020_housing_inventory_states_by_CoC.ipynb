# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("src/data/housing/2007-2020-Housing Inventory Count-Counts-by-CoC.xlsx - 2020.csv")

# %%
df.head()
# Out:
#   CoC Number  Total Year-Round Beds (ES, TH, SH)  \
# 0     AK-500                                 920
# 1     AK-501                                 965
# 2     AL-500                                 888
# 3     AL-501                                 396
# 4     AL-502                                 285
#
#    Total Non-DV Year-Round Beds (ES, TH, SH)  \
# 0                                        843
# 1                                        504
# 2                                        767
# 3                                        321
# 4                                         95
#
#    Total HMIS Year-Round Beds (ES, TH, SH)  \
# 0                                      666
# 1                                      456
# 2                                      612
# 3                                      321
# 4                                        0
#
#   HMIS Participation Rate for Year-Round Beds (ES, TH, SH)  \
# 0                                             72.39%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 77 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   CoC Number                                                 392 non-null    object
#  1   Total Year-Round Beds (ES, TH, SH)                         392 non-null    int64
#  2   Total Non-DV Year-Round Beds (ES, TH, SH)                  392 non-null    int64
#  3   Total HMIS Year-Round Beds (ES, TH, SH)                    392 non-null    int64
#  4   HMIS Participation Rate for Year-Round Beds (ES, TH, SH)   392 non-null    object
#  5   Total Year-Round Beds (ES)                                 392 non-null    int64
#  6   Total Year-Round Beds (TH)                                 392 non-null    int64
#  7   Total Year-Round Beds (SH)                                 392 non-null    int64
# ...

# %%
df.shape
# Out:
# (392, 77)

# %%
df.nunique()
# Out:
# CoC Number                                                  392
# Total Year-Round Beds (ES, TH, SH)                          332
# Total Non-DV Year-Round Beds (ES, TH, SH)                   323
# Total HMIS Year-Round Beds (ES, TH, SH)                     309
# HMIS Participation Rate for Year-Round Beds (ES, TH, SH)    371
#                                                            ...
# Total Beds for Households with Children (OPH)                96
# Total Beds for Households without Children (OPH)            103
# Total Beds for Households with only Children (OPH)            8
# Dedicated Veteran Beds (OPH)                                 38
# Dedicated Youth Beds (OPH)                                   23
# Length: 77, dtype: int64

# %%
col = df.select_dtypes('object').columns
for j in range(1,len(col)):
        df[col[j]] = df[col[j]].str.replace("%" , "")

for i in range(1,len(col)):
    df[col[i]] = pd.to_numeric(df[col[i]], errors='coerce')

# %%
col_1 = df.select_dtypes('float64').columns
for k in range(len(col_1)):
    df[col_1[k]] = df[col_1[k]] / 100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 77 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   CoC Number                                                 392 non-null    object
#  1   Total Year-Round Beds (ES, TH, SH)                         392 non-null    int64
#  2   Total Non-DV Year-Round Beds (ES, TH, SH)                  392 non-null    int64
#  3   Total HMIS Year-Round Beds (ES, TH, SH)                    392 non-null    int64
#  4   HMIS Participation Rate for Year-Round Beds (ES, TH, SH)   392 non-null    float64
#  5   Total Year-Round Beds (ES)                                 392 non-null    int64
#  6   Total Year-Round Beds (TH)                                 392 non-null    int64
#  7   Total Year-Round Beds (SH)                                 392 non-null    int64
# ...

# %%
df = df.drop(columns = ['CoC Number','Total Year-Round Beds (ES).1','Total Year-Round Beds (TH).1','Total Year-Round Beds (SH).1','HMIS Participation Rate for Year-Round Beds (SH)', 'HMIS Participation Rate for Year-Round Beds (OPH)'])

# %%
df.describe()
# Out:
#        Total Year-Round Beds (ES, TH, SH)  \
# count                          392.000000
# mean                          2021.168367
# std                          20377.002855
# min                             13.000000
# 25%                            209.500000
# 50%                            401.500000
# 75%                            920.250000
# max                         396149.000000
#
#        Total Non-DV Year-Round Beds (ES, TH, SH)  \
# count                                 392.000000
# mean                                 1769.647959
# std                                 17906.948709
# min                                     0.000000
# 25%                                   161.000000
# 50%                                   337.500000
# 75%                                   767.750000
# max                                346851.000000
#
#        Total HMIS Year-Round Beds (ES, TH, SH)  \
# count                               392.000000
# ...

# %%
droplist = [col for col in df.columns if (df[col]== 0).sum() > 75]

# %%
droplist
# Out:
# ['Total Year-Round Beds (SH)',
#  'Total Beds for Households with only Children (ES, TH, SH)',
#  'Dedicated Veteran Beds (ES, TH, SH)',
#  'Dedicated Youth Beds (ES, TH, SH)',
#  'Total Seasonal Beds (ES)',
#  'Total Overflow Beds (ES)',
#  'Total Beds for Households with only Children (ES)',
#  'Dedicated Veteran Beds (ES)',
#  'Dedicated Youth Beds (ES)',
#  'Total Beds for Households with only Children (TH)',
#  'Dedicated Veteran Beds (TH)',
#  'Dedicated Youth Beds (TH)',
#  'Total Non-DV Year-Round Beds (SH)',
#  'Total HMIS Year-Round Beds (SH)',
#  'Total Units for Households with Children (SH)',
#  'Total Beds for Households with Children (SH)',
#  'Total Beds for Households without Children (SH)',
#  'Total Beds for Households with only Children (SH)',
#  'Dedicated Veteran Beds (SH)',
#  'Dedicated Youth Beds (SH)',
#  'Total Beds for Households with only Children (RRH)',
#  'Dedicated Veteran Beds (RRH)',
#  'Dedicated Youth Beds (RRH)',
# ...

# %%
df.drop(droplist,axis=1,inplace=True)

# %%
df
# Out:
#      Total Year-Round Beds (ES, TH, SH)  \
# 0                                   920
# 1                                   965
# 2                                   888
# 3                                   396
# 4                                   285
# ..                                  ...
# 387                                 202
# 388                                 278
# 389                                 893
# 390                                 804
# 391                              396149
#
#      Total Non-DV Year-Round Beds (ES, TH, SH)  \
# 0                                          843
# 1                                          504
# 2                                          767
# 3                                          321
# 4                                           95
# ..                                         ...
# 387                                        180
# 388                                        234
# ...

# %%
df.describe()
# Out:
#        Total Year-Round Beds (ES, TH, SH)  \
# count                          392.000000
# mean                          2021.168367
# std                          20377.002855
# min                             13.000000
# 25%                            209.500000
# 50%                            401.500000
# 75%                            920.250000
# max                         396149.000000
#
#        Total Non-DV Year-Round Beds (ES, TH, SH)  \
# count                                 392.000000
# mean                                 1769.647959
# std                                 17906.948709
# min                                     0.000000
# 25%                                   161.000000
# 50%                                   337.500000
# 75%                                   767.750000
# max                                346851.000000
#
#        Total HMIS Year-Round Beds (ES, TH, SH)  \
# count                               392.000000
# ...

# %%
df = df.fillna(df.mean())

# %%
df = df.drop(axis = 0, index = 391)

# %%
df.head()
# Out:
#    Total Year-Round Beds (ES, TH, SH)  \
# 0                                 920
# 1                                 965
# 2                                 888
# 3                                 396
# 4                                 285
#
#    Total Non-DV Year-Round Beds (ES, TH, SH)  \
# 0                                        843
# 1                                        504
# 2                                        767
# 3                                        321
# 4                                         95
#
#    Total HMIS Year-Round Beds (ES, TH, SH)  \
# 0                                      666
# 1                                      456
# 2                                      612
# 3                                      321
# 4                                        0
#
#    HMIS Participation Rate for Year-Round Beds (ES, TH, SH)  \
# 0                                             0.7239
# 1                                             0.4725
# ...

# %%
df.shape
# Out:
# (391, 37)

# %%
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# Drop features 
df.drop(to_drop, axis=1, inplace=True)
# Out:
# <ipython-input-21-131161669abb>:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %%
df.shape
# Out:
# (391, 17)

# %%
to_drop
# Out:
# ['Total Non-DV Year-Round Beds (ES, TH, SH)',
#  'Total HMIS Year-Round Beds (ES, TH, SH)',
#  'Total Year-Round Beds (ES)',
#  'Total Units for Households with Children (ES, TH, SH)',
#  'Total Beds for Households with Children (ES, TH, SH)',
#  'Total Beds for Households without Children (ES, TH, SH)',
#  'Total Non-DV Year-Round Beds (ES)',
#  'Total HMIS Year-Round Beds (ES)',
#  'Total Units for Households with Children (ES)',
#  'Total Beds for Households with Children (ES)',
#  'Total Beds for Households without Children (ES)',
#  'Total Non-DV Year-Round Beds (TH)',
#  'Total Beds for Households with Children (TH)',
#  'Total Non-DV Year-Round Beds (RRH)',
#  'Total HMIS Year-Round Beds (RRH)',
#  'Total Units for Households with Children (RRH)',
#  'Total Beds for Households with Children (RRH)',
#  'Total Non-DV Year-Round Beds (PSH)',
#  'Total Beds for Households with Children (PSH)',
#  'Total Beds for Households without Children (PSH)']

# %%
df.head()
# Out:
#    Total Year-Round Beds (ES, TH, SH)  \
# 0                                 920
# 1                                 965
# 2                                 888
# 3                                 396
# 4                                 285
#
#    HMIS Participation Rate for Year-Round Beds (ES, TH, SH)  \
# 0                                             0.7239
# 1                                             0.4725
# 2                                             0.6892
# 3                                             0.8106
# 4                                             0.0000
#
#    Total Year-Round Beds (TH)  \
# 0                         200
# 1                         275
# 2                         309
# 3                         122
# 4                         167
#
#    HMIS Participation Rate for Year-Round Beds (ES)  \
# 0                                            0.6972
# 1                                            0.4072
# ...
