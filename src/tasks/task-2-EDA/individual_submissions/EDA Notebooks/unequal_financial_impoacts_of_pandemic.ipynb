# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/OmdenaAI/omdena-texas-homelessness/main/src/data/employment/Unequal%20Financial%20Impacts%20of%20the%20Pandemic%20(HPS)%20by%20Quarter.xlsx%20-%20Sheet1.csv?token=AUHOKXLMYPS3LOCRIE7ZWA3BL4WH6')
df.head()
# Out:
#        Unnamed: 0            Renters Unnamed: 2       Unnamed: 3  \
# 0  Quarter 4 2020                NaN   <$25,000  $25,000-$49,999
# 1             NaN  Behind on Housing       24.0             19.1
# 2             NaN     Loss of Income       55.4             56.7
# 3             NaN                NaN      White            Black
# 4             NaN  Behind on Housing       11.8             27.9
#
#        Unnamed: 4      Unnamed: 5                Unnamed: 6 Unnamed: 7  \
# 0  $50,000-74,999  $75,000-99,999                 $100,000+        All
# 1            12.8             9.3                       6.2       17.0
# 2            52.6            47.1                      40.3       52.8
# 3        Hispanic           Asian  Another Race/Multiracial        All
# 4            20.7            17.5                      20.9       17.0
#
#   Homeowners       Unnamed: 9     Unnamed: 10     Unnamed: 11  \
# 0   <$25,000  $25,000-$49,999  $50,000-74,999  $75,000-99,999
# ...

# %% [markdown]
# This dataset has too much and is too spread apart. Rows are columns, no real direction on what is what with no source. We will not recommend the use of this dataset. It could be of some value if the data is parsed with another set that could define the data a bit more.

# %%
df.to_csv('unequal_financial_impacts_of_the_pandemic_by_quarter')
